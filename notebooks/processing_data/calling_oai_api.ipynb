# %%
curl -sS http://roti:8000/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{
    "model": "deepseek-r1-llama-8b-awq",
    "messages": [
      {
        "role": "user",
        "content": "Say hello in one sentence."
      }
    ],
    "temperature": 0.7,
    "max_tokens": 128
  }' | jq

# %%
curl -N -sS http://roti:8000/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{
    "model": "deepseek-r1-llama-8b-awq",
    "messages": [
      {
        "role": "user",
        "content": "Count from 1 to 10 slowly."
      }
    ],
    "temperature": 0.7,
    "max_tokens": 128,
    "stream": true
  }'
